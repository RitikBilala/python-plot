# %% [markdown]
# # Chapter 1: Matplotlib is a library in python : Basics

# %% [markdown]
# Import Module

# %%
import matplotlib.pyplot as plt

# %%
X = range(100);
Y = [i**2 for i in X]

# %%
plt.plot(X,Y)
plt.show()

# %% [markdown]
# ## Task 1.0: use numpy to plot

# %%
import numpy as np

# %% [markdown]
# Create points to plot using numpy

# %%
x = np.arange(0,100,10)
y = np.power(x,3)

# %% [markdown]
# Matplolib is used here :
# remember : linestyle, marker, color creates features
# <br>Dont be anxious ,we will discover more features in coming lectures

# %%
#y = np.square(x) can be use for element-wise square
plt.plot(x, y, linestyle="dashed", marker="o", color="green")
plt.show()
